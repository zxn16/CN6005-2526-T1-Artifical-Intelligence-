# %% [markdown]
# <a href="https://colab.research.google.com/github/zxn16/CN6005-2526-T1-Artifical-Intelligence-/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Week 3 tasks

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np

# Separate features and target, dropping 'Name', 'PassengerId', and 'Ticket'
features = df_titanic.drop(['Survived', 'Name', 'PassengerId', 'Ticket'], axis=1)
target = df_titanic['Survived']

# Identify categorical and numerical features present in the features DataFrame
categorical_features = ['Sex', 'Embarked']
numerical_features = ['Age', 'Fare', 'Pclass']

# Filter categorical_features to include only columns present in 'features'
categorical_features = [col for col in categorical_features if col in features.columns]

# Create transformers for preprocessing
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a column transformer to apply different transformations to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'
)

# Apply preprocessing to the features
features_processed = preprocessor.fit_transform(features)

display(features_processed[:5])
# Out:
# array([[-0.56573646, -0.50244517,  0.82737724,  0.        ,  1.        ],
#        [ 0.66386103,  0.78684529, -1.56610693,  1.        ,  0.        ],
#        [-0.25833709, -0.48885426,  0.82737724,  1.        ,  0.        ],
#        [ 0.4333115 ,  0.42073024, -1.56610693,  1.        ,  0.        ],
#        [ 0.4333115 , -0.48633742,  0.82737724,  0.        ,  1.        ]])

# %%
from sklearn.metrics import accuracy_score

# Predict on the test set using the KNN model
y_pred_knn = knn_model.predict(X_test)

# Calculate the accuracy of the KNN model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f"Accuracy of KNN model: {accuracy_knn:.4f}")

# Predict on the test set using the Logistic Regression model
y_pred_logreg = logreg_model.predict(X_test)

# Calculate the accuracy of the Logistic Regression model
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f"Accuracy of Logistic Regression model: {accuracy_logreg:.4f}")
# Out:
# Accuracy of KNN model: 0.8156
# Accuracy of Logistic Regression model: 0.7989

# %%
from sklearn.linear_model import LogisticRegression

# Create a Logistic Regression model
logreg_model = LogisticRegression()

# Train the model
logreg_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier with k=5 (you can adjust k)
knn_model = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features_processed, target, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (712, 5)
# Shape of X_test: (179, 5)
# Shape of y_train: (712,)
# Shape of y_test: (179,)

# %%
import pandas as pd

df_titanic = pd.read_csv('/content/titanic (1).csv')
display(df_titanic.head(500))
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 495          496       3                              Yousseff, Mr. Gerious
# 496          497       1                     Eustis, Miss. Elizabeth Mussey
# 497          498       3                    Shellard, Mr. Frederick William
# 498          499       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 499          500       3                                 Svensson, Mr. Olof
#
#         Sex   Age            Ticket      Fare  Survived
# ...

# %% [markdown]
# **Summary of Titanic Survival Prediction Project:**

# %% [markdown]
# In this project, we aimed to predict survival on the Titanic using Machine Learning models. We performed the following steps:
#
# 1.  **Data Loading**: Loaded the Titanic dataset.
# 2.  **Data Preprocessing**: Handled missing values, scaled numerical features, and encoded categorical features. Irrelevant columns ('Name', 'PassengerId', 'Ticket') were removed.
# 3.  **Data Splitting**: Divided the data into training and testing sets.
# 4.  **Model Building and Training**: Built and trained both K-Nearest Neighbors (KNN) and Logistic Regression classification models.
# 5.  **Model Evaluation**: Evaluated the accuracy of both models on the test set.
#
# **Learnings:**
#
# *   We successfully applied data preprocessing techniques essential for machine learning.
# *   We implemented and trained two common classification algorithms: KNN and Logistic Regression.
# *   We evaluated model performance using accuracy, finding that the KNN model performed slightly better in this instance.
#
# This project demonstrated a basic workflow for a classification task, from data preparation to model evaluation.
